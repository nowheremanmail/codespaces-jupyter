# %% [markdown]
# <div style="width: 100%; clear: both;">
#     <div style="float: left; width: 50%;">
#        <img src="http://www.uoc.edu/portal/_resources/common/imatges/marca_UOC/UOC_Masterbrand.jpg", align="left">
#     </div>
# </div>
#
# <div style="float: right; width: 50%;">
#     <p style="margin: 0; padding-top: 22px; text-align:right;">M1.771 · Privacidad</p>
#     <p style="margin: 0; text-align:right;">Máster Universitario en Ciberseguridad y Privacidad</p>
#     <p style="margin: 0; text-align:right; padding-button: 100px;">Estudios de Informática, Multimedia y Telecomunicación</p>
# </div>
#
# </div>
# <div style="width: 100%; clear: both;">
# <div style="width:100%;">&nbsp;</div>

# %% [markdown]
# Privadesa
# ============================
#
# ---
#
# PEC2 - Actividad 1 con datos de Lightbeam
# -----------------------------------------------------
#
# Este *notebook* es una herramienta para responder a las preguntas planteadas en
# la activitad 1 de la PEC2.
#
# ### Introducción
# El conjunto de datos con el que vamos a trabajar (`ThunderbeamData.json`)
# consta de las páginas registradas con Lightbeam, la extensión del navegador
# que utiliza visualizaciones interactivas para mostrarnos las relaciones entre
# terceros y las páginas que visitamos.

# %%
import pandas as pd
import json

# Generamos un dataframe con los datos que hemos descargado del Lightbeam.
df = pd.read_json('../data/ThunderbeamData.json')
df = df.transpose()

# # Restringimos los registros a las páginas que hemos visitado.
pagina = df[df.firstParty == True]

# %%
# Imprimimos las columnas del dataframe que hemos cargado.
print(pagina.columns.values)

# Imprimimos la lista de páginas que hemos visitado.
print(pagina.hostname)
# Out:
# ['hostname' 'firstPartyHostnames' 'firstParty' 'thirdParties']
# blogs.elconfidencial.com    blogs.elconfidencial.com
# consent.yahoo.com                  consent.yahoo.com
# edition.cnn.com                      edition.cnn.com
# elpais.com                                elpais.com
# extensions                                extensions
# flipboard.com                          flipboard.com
# newtab                                        newtab
# thehackernews.com                  thehackernews.com
# thenextweb.com                        thenextweb.com
# www.amazon.es                          www.amazon.es
# www.bbc.com                              www.bbc.com
# www.bing.com                            www.bing.com
# www.cnet.com                            www.cnet.com
# www.darkreading.com              www.darkreading.com
# www.elconfidencial.com        www.elconfidencial.com
# www.elperiodico.com              www.elperiodico.com
# www.engadget.com                    www.engadget.com
# www.gobankingrates.com        www.gobankingrates.com
# www.google.com                        www.google.com
# www.microsiervos.com            www.microsiervos.com
# www.microsoft.com                  www.microsoft.com
# www.pcworld.com                      www.pcworld.com
# www.theregister.com              www.theregister.com
# www.theverge.com                    www.theverge.com
# www.wired.com                          www.wired.com
# Name: hostname, dtype: object

# %%
# Generamos las parejas de páginas, la lista de terceros en común, y cuántos son.
PaginesTercers = [[pagina.hostname[u], 
                   pagina.hostname[v], 
                   list(set(pagina.thirdParties[u]) & set(pagina.thirdParties[v])), 
                   len(list(set(pagina.thirdParties[u]) & set(pagina.thirdParties[v])))]
                  for u in pagina.index 
                  for v in pagina.index
                  if u != v]

# Convertimos los datos que hemos calculado en un dataframe.
PaginesTercers = pd.DataFrame(PaginesTercers, 
                              columns = ['Pagina1', 
                                         'Pagina2', 
                                         'TercersEnComu', 
                                         'Interseccio'])

# %%
# Calculamos cuáles son las páginas que tienen más terceros en común.
PaginesTercers.iloc[PaginesTercers.Interseccio.idxmax()]
# Out:
# Pagina1                                   blogs.elconfidencial.com
# Pagina2                                     www.elconfidencial.com
# TercersEnComu    [www.google.com, mwzeom.zeotap.com, pixel.rubi...
# Interseccio                                                    103
# Name: 13, dtype: object

# %%
ordenados_por_inter = PaginesTercers.sort_values(['Interseccio'], ascending=[False])
print(ordenados_por_inter[['Pagina1','Pagina2','Interseccio']])

# mostramos los 3 primeros
print(ordenados_por_inter.loc[13])
print(ordenados_por_inter.loc[336])
print(ordenados_por_inter.loc[339])
# Out:
#                       Pagina1                   Pagina2  Interseccio
# 13   blogs.elconfidencial.com    www.elconfidencial.com          103
# 336    www.elconfidencial.com  blogs.elconfidencial.com          103
# 339    www.elconfidencial.com                elpais.com           64
# 85                 elpais.com    www.elconfidencial.com           64
# 374       www.elperiodico.com    www.elconfidencial.com           60
# ..                        ...                       ...          ...
# 107                extensions              www.cnet.com            0
# 106                extensions              www.bing.com            0
# 105                extensions               www.bbc.com            0
# 104                extensions             www.amazon.es            0
# 0    blogs.elconfidencial.com         consent.yahoo.com            0
#
# [600 rows x 3 columns]
# Pagina1                                   blogs.elconfidencial.com
# Pagina2                                     www.elconfidencial.com
# TercersEnComu    [www.google.com, mwzeom.zeotap.com, pixel.rubi...
# Interseccio                                                    103
# Name: 13, dtype: object
# Pagina1                                     www.elconfidencial.com
# Pagina2                                   blogs.elconfidencial.com
# TercersEnComu    [www.google.com, mwzeom.zeotap.com, pixel.rubi...
# Interseccio                                                    103
# Name: 336, dtype: object
# Pagina1                                     www.elconfidencial.com
# Pagina2                                                 elpais.com
# TercersEnComu    [www.google.com, ads.pubmatic.com, www.faceboo...
# Interseccio                                                     64
# Name: 339, dtype: object

# %%
from functools import reduce

terceros = reduce(lambda a,b: set(a) | set(b), [set(pagina.thirdParties[v]) for v in pagina.index])

print(terceros)

print("tamaños de el conjunto de terceros únicos " + str(len(terceros)))
# Out:
# {'m.media-amazon.com', 'tt.onthe.io', '9496895ef0c13f62e738d01127d1b263.safeframe.googlesyndication.com', 'cdn0.tnwcdn.com', 'sync.sharethis.com', 'condenast-privacy.my.onetrust.com', 'media.wired.com', 'buy.tinypass.com', '834d0071f14ebba6a2a09576ecf608a1.safeframe.googlesyndication.com', 'experience-eu.piano.io', 'api.amplitude.com', 'tps.doubleverify.com', 'a6709203f34992a5095d2bc7ceaf2ec504f651a8.cws.conviva.com', 'trk.darkreading.com', 'pub.doubleverify.com', 'tse1.explicit.bing.net', 'media.adrcdn.com', 'es-gmtdmp.mookie1.com', 'consent.cmp.oath.com', 'a.pub.network', 'beacon.krxd.net', 'bucket.cdnwebcloud.com', 'idcta.api.bbc.co.uk', 'api.sail-personalize.com', 'cdn.concert.io', 'cdnssl.clicktale.net', 'ads.stickyadstv.com', 'cdn.optimizely.com', 'kmzrq6af76i6czj45kbq-p6jd2n-fa957ba9d-clientnsv4-s.akamaihd.net', 'tse2.mm.bing.net', 'cdn.cxense.com', 'exch.quantserve.com', 'static.iris.informa.com', 'vtrk.doubleverify.com', 'tags.crwdcntrl.net', 'b1sync.zemanta.com', 'globalservices.conde.digital', 'feed.pghub.io', 'login.microsoftonline.com', 't.pubmatic.com', 'creativecdn.com', 'ak.sail-horizon.com', 'ids.cdnwidget.com', 'services.insurads.com', 'compassdata.mrf.io', 'px.owneriq.net', 'signal-metrics-collector-beta.s-onetag.com', 'd2fb08da-1c03-4c8a-978f-ad8a96b4c31f.prmutv.co', 'video-edge-03f0ce.pdx01.abs.hls.ttvnw.net', '3p-geo.yahoo.com', 'connect-metrics-collector.s-onetag.com', 'functions.adnami.io', 'gn-web-assets.api.bbc.com', 'image2.pubmatic.com', 'video.twimg.com', 'ntvcld-a.akamaihd.net', 'cdn.adnxs.com', 'vis.vi-serve.com', 'bbc.gscontxt.net', 'assets.jivox.com', 'sdk.privacy-center.org', 'mybbc.files.bbci.co.uk', 'emp.bbci.co.uk', 'prebid.media.net', 'region1.analytics.google.com', 'gem.gbc.criteo.com', 'content.zeotap.com', '14a7dd931ada41774ba90776821892fb.safeframe.googlesyndication.com', 'static.files.bbci.co.uk', 'cdn.indexww.com', 'turnip.cdn.turner.com', 'services.brightline.tv', 'js.memberful.com', 'ups.analytics.yahoo.com', 'ap.lijit.com', 'pghub.io', 'track4.aniview.com', 'www.googletagmanager.com', '1f2421d78e476fffb3be1341a8df977e.safeframe.googlesyndication.com', 'ed5ac1e0016a9733420ddc5966c2efef.safeframe.googlesyndication.com', 'cdn.adsafeprotected.com', 'sync.extend.tv', 'at.teads.tv', 'p.ad.gt', 'zion-telemetry.api.cnn.io', 'ib.3lift.com', 'pixel.tapad.com', 'cdn.unblockia.com', 'bttrack.com', 'sdk.mrf.io', 'nir.theregister.com', 'publicapi.elpais.com', 'cnn.bounceexchange.com', '0217991b.akstat.io', 'ad.doubleclick.net', '1698490928506df0da0f5d312693e8d1909836c4af18d8a7d7d29298.trk.sensic.net', 'm.hb.yahoo.net', 'mboxedge37.tt.omtrdc.net', 'x.bidswitch.net', 'jadserve.postrelease.com', 't.seedtag.com', 'apps.voxmedia.com', 'rtb0.doubleverify.com', 'cdn3.optimizely.com', 'cdn.boomtrain.com', '1f7330f82a2ec54bf59621c97d74550b.safeframe.googlesyndication.com', 'secure.cdn.fastclick.net', 'eu-notify-rtb.quantserve.com', 'r1---sn-h5qzen76.c.2mdn.net', 'match.sharethrough.com', 'prebid.adnxs.com', 'clients1.google.com', 'static.doubleclick.net', 'videoevents.outbrain.com', 'cds.taboola.com', 'i.clean.gg', 'a4407.casalemedia.com', 'eu-u.openx.net', 'creatives.sascdn.com', 'launchpad.privacymanager.io', 'capture.condenastdigital.com', 'odr.mookie1.com', 'www.google.es', 'cm.smadex.com', 'js-agent.newrelic.com', 'tse3.mm.bing.net', 'bat.bing.com', 'macro.adnami.io', 'a125375509.cdn.optimizely.com', 'analytics.prensaiberica.es', 'events.bouncex.net', 'sync-amz.ads.yieldmo.com', 'cdfd9ada942210d34c3f3feee5f76bc0.safeframe.googlesyndication.com', 'track.adform.net', 'znbfkexqbr8elolwk-redventures.siteintercept.qualtrics.com', 's0.2mdn.net', 'www8.smartadserver.com', 'servedby.flashtalking.com', 'idplus.zeotap.com', 'p.skimresources.com', 'img.en25.com', 'use.fontawesome.com', 's.amazon-adsystem.com', 'mpc.nicequest.com', 'vap3ams1.lijit.com', 'martech.condenastdigital.com', 'adx.adform.net', 'cdn.amplitude.com', 'static.elpais.com', 'prebid.the-ozone-project.com', 'bidder.criteo.com', 'www.tradingvi ...
# tamaños de el conjunto de terceros únicos 884

# %%
# calculamos columna con el número de third parties
df['numero_third_parties'] = df.apply(lambda row: len(row['thirdParties']), axis=1)

# ordenamos descendientemente por el número, filtrando con páginas visitadas
ordenado = df.sort_values(['numero_third_parties'], ascending=[False])[df.firstParty == True]

print (ordenado[['hostname','numero_third_parties']])
# Out:
#                                           hostname  numero_third_parties
# www.elconfidencial.com      www.elconfidencial.com                   232
# edition.cnn.com                    edition.cnn.com                   189
# www.pcworld.com                    www.pcworld.com                   165
# www.theverge.com                  www.theverge.com                   142
# elpais.com                              elpais.com                   129
# blogs.elconfidencial.com  blogs.elconfidencial.com                   124
# www.elperiodico.com            www.elperiodico.com                   122
# www.wired.com                        www.wired.com                    98
# www.microsiervos.com          www.microsiervos.com                    72
# www.cnet.com                          www.cnet.com                    71
# www.bbc.com                            www.bbc.com                    66
# www.gobankingrates.com      www.gobankingrates.com                    66
# www.darkreading.com            www.darkreading.com                    47
# www.engadget.com                  www.engadget.com                    42
# flipboard.com                        flipboard.com                    29
# www.microsoft.com                www.microsoft.com                    28
# www.theregister.com            www.theregister.com                    27
# thenextweb.com                      thenextweb.com                    19
# www.amazon.es                        www.amazon.es                    18
# www.bing.com                          www.bing.com                    17
# www.google.com                      www.google.com                    12
# thehackernews.com                thehackernews.com                     9
# consent.yahoo.com                consent.yahoo.com                     2
# newtab                                      newtab                     0
# extensions                              extensions                     0
# /tmp/ipykernel_42812/2480939855.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ordenado = df.sort_values(['numero_third_parties'], ascending=[False])[df.firstParty == True]

# %%
from functools import reduce
import statistics
from statistics import mode

lista_todos_terceros = reduce(lambda a,b: a + b, [pagina.thirdParties[v] for v in pagina.index])

print(lista_todos_terceros)

print("tamaño lista de todos los terceros " + str(len(lista_todos_terceros)))

print("el tercero mas frecuente es " + mode(lista_todos_terceros))
# Out:
# ['pagead2.googlesyndication.com', 'sdk.privacy-center.org', 'delorean.ecestaticos.com', 'images.ecestaticos.com', 'track.adform.net', 's1.adform.net', 'ade.googlesyndication.com', 'access.elconfidencial.com', 'sdk.mrf.io', 'es-config.sensic.net', 'accounts.google.com', 'sb.scorecardresearch.com', 'ads.pubmatic.com', 'fc-id.sensic.net', 'ats-wrapper.privacymanager.io', 'events.newsroom.bi', 'es1-s2s.sensic.net', 'ut.pubmatic.com', 'securepubads.g.doubleclick.net', 'api.amplitude.com', 'www.npttech.com', 'flowcards.mrf.io', '1698489652068c759b2f823d32a83f8b7df75da8c4c32f0e74b697fc.trk.sensic.net', 'api.elconfidencial.com', 'compassdata.mrf.io', 'www.googletagmanager.com', 'cdn.insurads.com', 'cdn.unblockia.com', 'www.google-analytics.com', 'cdn.id5-sync.com', 'cdn.jsdelivr.net', 'cdn.prod.uidapi.com', 'tags.crwdcntrl.net', 'invstatic101.creativecdn.com', 'oa.openxcdn.net', 'static.criteo.net', 'cdn-ima.33across.com', 'gum.criteo.com', 'hbopenbid.pubmatic.com', 'ib.adnxs.com', 'www.googleadservices.com', 'htlb.casalemedia.com', 'bidder.criteo.com', 'fastlane.rubiconproject.com', 'prg.smartadserver.com', 'connect.facebook.net', 'dnacdn.net', 'useridentity.elconfidencial.com', 'acdn.adnxs.com', 'js-sec.indexww.com', 'id5-sync.com', 'eus.rubiconproject.com', 'ssp-sync.criteo.com', 'ee2bb5853753c660dfc337ca1a25eb50.safeframe.googlesyndication.com', 'spl.zeotap.com', 'tpc.googlesyndication.com', 'sync-tm.everesttech.net', 'geo.privacymanager.io', 'www.facebook.com', 'www.google.com', 'rtb-csync.smartadserver.com', 'loader.unblockia.com', 'cm.g.doubleclick.net', 'api.rlcdn.com', 'match.adsrvr.org', 'oajs.openx.net', 'idplus.zeotap.com', 't.unblockia.com', 'google-bidout-d.openx.net', 'www.google.es', 'mwzeom.zeotap.com', 'cdn.tinypass.com', 'cdn.cxense.com', 'content.zeotap.com', 'region1.analytics.google.com', 'fonts.googleapis.com', 'www.googletagservices.com', 'www.gstatic.com', 'c2.piano.io', 'news.google.com', 'fonts.gstatic.com', 'ssum-sec.casalemedia.com', 'token.rubiconproject.com', 'p1cluster.cxense.com', 'play.google.com', 'gem.gbc.criteo.com', 'ag.gbc.criteo.com', 'cdn.indexww.com', 't.pubmatic.com', 'comcluster.cxense.com', 'pixel.rubiconproject.com', 'live.primis.tech', 's2s.t13.io', 'sync.outbrain.com', 'usync.vrtcal.com', 'buy.tinypass.com', 'googleads.g.doubleclick.net', 'ad.doubleclick.net', 's0.2mdn.net', 'tracking.smartmeapp.com', 'googleads4.g.doubleclick.net', 'code.createjs.com', 'services.insurads.com', 'www.elconfidencial.com', '16984909402634fd9c604bfba8ca23e0887555694c350afba4ea38e4.trk.sensic.net', 'bcf563afd85ecec6f56d1236781a1bf0.safeframe.googlesyndication.com', 'web-messaging.insurads.com', 'c.amazon-adsystem.com', 'config.aps.amazon-adsystem.com', 'aax.amazon-adsystem.com', 'aax-eu.amazon-adsystem.com', 'match.sharethrough.com', 's.ad.smaato.net', 'onetag-sys.com', 'ap.lijit.com', 'sync-amz.ads.yieldmo.com', 'b1sync.zemanta.com', 's.amazon-adsystem.com', 'x.bidswitch.net', 'ads.yieldmo.com', 'prebid.media.net', '49ff9b613f1e6a03a1969618c217fff2.safeframe.googlesyndication.com', 'contextual.media.net', 'image6.pubmatic.com', 's.yimg.com', 'www.engadget.com', 'elb.the-ozone-project.com', 'uk-script.dotmetrics.net', 'tpsc-ew1.doubleverify.com', 'pagead2.googlesyndication.com', 'media.cnn.com', 'lightning.cnn.com', 'cdn.optimizely.com', 'ade.googlesyndication.com', 'z.cdp-dev.cnn.com', 'cdn.cookielaw.org', 'get.s-onetag.com', 'registry.api.cnn.io', 'cdn.jsdelivr.net', 'static.chartbeat.com', 'cdn.ml314.com', 'sb.scorecardresearch.com', 'cdn3.optimizely.com', 'a125375509.cdn.optimizely.com', 'tag.bounceexchange.com', 'vi.ml314.com', 'secure.quantserve.com', 'secure-us.imrworldwide.com', 'www.ugdturner.com', 'widgets.outbrain.com', 'live.rezync.com', 'onetag-geo.s-onetag.com', 'signal-beacon.s-onetag.com', 'rules.quantcount.com', 'assets.bounceexchange.com', 'mab.chartbeat.com', 'cdn.boomtrain.com', 'widget-pixels.outbrain.com', 'dpm.demdex.net', 'collector.cdp.cnn.com', 'logx.optimizely.com', 'ping.chartbeat. ...
# tamaño lista de todos los terceros 1726
# el tercero mas frecuente es www.google.com
